# %%
# -*- coding: utf-8 -*- 
from collections import OrderedDict
import xmltodict

input_filename = "courses.xml"
# this step takes a while
with open(input_filename) as f:
    doc = xmltodict.parse(f.read())

# %%
def collapse(the_dict, field1, field2):
    if (
        the_dict
        and field1 in the_dict
        and the_dict[field1]
        and field2 in the_dict[field1]
    ):
        if type(the_dict[field1][field2]) is list:
            the_dict[field1] = the_dict[field1][field2]
        else:
            the_dict[field1] = [the_dict[field1][field2]]
            
for course in doc["xml"]["courses"]["course"]:
    # parsing xml has some redundancies. We'll collapse those 
    # to make the final object easier to read through
    collapse(course, "sections", "section")
    collapse(course, "attributes", "attribute")
    collapse(course, "tags", "tag")
    collapse(course, "learningObjectives", "learningObjective")

    if "sections" in course and course["sections"]:
        for section in course["sections"]:
            collapse(section, "attributes", "attribute")
            collapse(section, "schedules", "schedule")
            if "schedules" in section and section["schedules"]:
                for schedule in section["schedules"]:
                    collapse(schedule, "instructors", "instructor")

# %%
a = doc["xml"]["courses"]["course"][:]
print("{} courses".format(len(a)))

h1_keys = a[0].keys()
h1_values = {k: set() for k, v in a[0].items()}
for i, course in enumerate(a):
    if course.keys() != h1_keys:
        print("diff keys")
        break
    for k, v in course.items():
        h1_values[k].add(type(v)) 

# print h1_keys
# print "**"
# print h1_values
# print "****"

for k, v in h1_values.items():
    print "{}: {}".format(k, v)
# Out:
# 14840 courses
# administrativeInformation: set([<class 'collections.OrderedDict'>])
# code: set([<type 'unicode'>])
# description: set([<type 'unicode'>, <type 'NoneType'>])
# title: set([<type 'unicode'>])
# grading: set([<type 'unicode'>])
# learningObjectives: set([<type 'list'>, <type 'NoneType'>])
# gers: set([<type 'unicode'>, <type 'NoneType'>])
# unitsMin: set([<type 'unicode'>])
# repeatable: set([<type 'unicode'>])
# year: set([<type 'unicode'>])
# attributes: set([<type 'list'>, <type 'NoneType'>])
# sections: set([<type 'list'>, <type 'NoneType'>])
# unitsMax: set([<type 'unicode'>])
# tags: set([<type 'list'>, <type 'NoneType'>])
# subject: set([<type 'unicode'>])

# %%
# analyzing top level fields

for i, course in enumerate(a):
    if i < 75:
        continue
    if i > 80:
        break
    for k, v in course.items():
        print "{}: {}".format(k, v)
    print("***")
# Out:
# year: 2017-2018
# subject: ACCT
# code: 210
# title: Financial Accounting
# description: Financial accounting is the measurement of economic activity for decision-making. Financial statements are a key product of this measurement process and an important component of firms' financial reporting activities. The objective of this course is not to train you to become an accountant but rather to help you develop into an informed user of financial statement information. While financial statement users face a wide variety of decisions, they are often interested in understanding the implications of financial statement information for the future cash flows and earnings potential of a firm. We will focus on understanding the mapping between underlying economic events and financial statements, and on understanding how this mapping affects inferences about future profitability and liquidity. The following learning objectives will be emphasized: (1) familiarity with the transactions businesses engage in, (2) fluency in accounting terminology, (3) understanding the structure that maps transactions into accounting numbers, (4) understanding the rationale for various accounting methods, and (5) awareness of the judgment involved and the discretion allowed in choosing accounting methods, making estimates, and disclosing information in financial statements.
# gers: None
# repeatable: false
# grading: GSB Letter Graded
# unitsMin: 4
# unitsMax: 4
# learningObjectives: None
# sections: [OrderedDict([(u'classId', u'29921'), (u'term', u'2017-2018 Autumn'), (u'termId', u'1182'), (u'subject', u'ACCT'), (u'code', u'210'), (u'units', u'4'), (u'sectionNumber', u'03'), (u'component', u'CAS'), (u'numEnrolled', u'54'), (u'maxEnrolled', u'72'), (u'numWaitlist', u'0'), (u'maxWaitlist', u'0'), (u'enrollStatus', u'Open'), (u'addConsent', u'D'), (u'dropConsent', u'D'), (u'courseId', u'100734'), (u'schedules', [OrderedDict([(u'startDate', u'Sep 25, 2017'), (u'endDate', u'Dec 8, 2017'), (u'startTime', u'10:00:00 AM'), (u'endTime', u'11:45:00 AM'), (u'location', u'GSB Class of 1968 102'), (u'days', u'Monday\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\tThursday'), (u'instructors', [OrderedDict([(u'name', u'Gipper, B.'), (u'firstName', u'Brandon'), (u'middleName', u'Lee'), (u'lastName', u'Gipper'), (u'sunet', u'gipperbr'), (u'role', u'PI')]), OrderedDict([(u'name', u'Wells, K.'), (u'firstName', u'Kelly'), (u'middleName', None), (u'lastName', u'Wells'), (u'sunet', u'kcwells7'), (u'role', u'GP')])])])]), (u'currentClassSize', u'54'), (u'maxClassSize', u'72'), (u'currentWaitlistSize', u'0'), (u'maxWaitlistSize', u'0'), (u'notes', u"Case and Problem Discussion. P/F Not Allowed. Open to MBA1 students. In-class Midterm and Final. Mandatory attendance. Absences impact grade. Not Open to Non-GSB Students. Final 40% Midterm 30% Participat'n 15% HW 15."), (u'attributes', OrderedDict([(u'attribute', [OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APFA'), (u'value', u'NTALLOW'), (u'description', u'P/F Not Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AAPP'), (u'value', u'MB1'), (u'description', u'Open to MBA1 students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AEXA'), (u'value', u'INCMD&FN'), (u'description', u'In-class Midterm and Final'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AATT'), (u'value', u'MANDATORY'), (u'description', u'Mandatory attendance. Absences impact grade.'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'ANON'), (u'value', u'NOTOPEN'), (u'description', u'Not Open to Non-GSB Students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AGRA'), (u'value', u'F40M30C15H'), (u'description', u"Final 40% Midterm 30% Participat'n 15% HW 15"), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])])]))]), OrderedDict([(u'classId', u'29919'), (u'term', u'2017-2018 Autumn'), (u'termId', u'1182'), (u'subject', u'ACCT'), (u'code', u'210'), (u'units', u'4'), (u'sectionNumber', u'01'), (u'component', u'CAS'), (u'numEnrolled', u'45'), (u'maxEnrolled', u'72'), (u'numWaitlist', u'0'), (u'maxWaitlist', u'0'), (u'enrollStatus', u'Open'), (u'addConsent', u'D'), (u'dropConsent', u'D'), (u'courseId', u'100734'), (u'schedules', [OrderedDict([(u'startDate', u'Sep 25, 2017'), (u'endDate', u'Dec 8, 2017'), (u'startTime', u'8:00:00 AM'), (u'endTime', u'9:45:00 AM'), (u'location', u'GSB Class of 1968 102'), (u'days', u'Monday\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\tThursday'), (u'instructors', [OrderedDict([(u'name', u'Gipper, B.'), (u'firstName', u'Brandon'), (u'middleName', u'Lee'), (u'lastName', u'Gipper'), (u'sunet', u'gipperbr'), (u'role', u'PI')]), OrderedDict([(u'name', u'Wells, K.'), (u'firstName', u'Kelly'), (u'middleName', None), (u'lastName', u'Wells'), (u'sunet', u'kcwells7'), (u'role', u'GP')])])])]), (u'currentClassSize', u'45'), (u'maxClassSize', u'72'), (u'currentWaitlistSize', u'0'), (u'maxWaitlistSize', u'0'), (u'notes', u"Case and Problem Discussion. P/F Not Allowed. Open to MBA1 students. In-class Midterm and Final. Mandatory attendance. Absences impact grade. Not Open to Non-GSB Students. Final 40% Midterm 30% P ...
# administrativeInformation: OrderedDict([(u'courseId', u'100734'), (u'effectiveStatus', u'A'), (u'offerNumber', u'1'), (u'academicGroup', u'GSB'), (u'academicOrganization', u'GSB'), (u'academicCareer', u'GSB'), (u'finalExamFlag', u'N'), (u'catalogPrint', u'Y'), (u'schedulePrint', u'Y'), (u'maxUnitsRepeat', u'4'), (u'maxTimesRepeat', u'1')])
# attributes: [OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APFA'), (u'value', u'NTALLOW'), (u'description', u'P/F Not Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AAPP'), (u'value', u'MB1'), (u'description', u'Open to MBA1 students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AEXA'), (u'value', u'INCMD&FN'), (u'description', u'In-class Midterm and Final'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AATT'), (u'value', u'MANDATORY'), (u'description', u'Mandatory attendance. Absences impact grade.'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'ANON'), (u'value', u'NOTOPEN'), (u'description', u'Not Open to Non-GSB Students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AGRA'), (u'value', u'F40M30C15H'), (u'description', u"Final 40% Midterm 30% Participat'n 15% HW 15"), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])]
# tags: [OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')]), OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')]), OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])]
# ***
# year: 2017-2018
# subject: ACCT
# code: 212
# title: Managerial Accounting: Base
# description: This course provides an introduction to the concepts and tools of managerial accounting. The first part of the course covers alternative costing methods and illustrates how the resulting cost information can be used to analyze the profitability of individual products and customers. The second part of the course will examine the role of internal accounting systems in evaluating the performance of individual business segments and divisions of the firm. Included in this part are topics related to the choice of internal pricing methods for transferring goods and services across divisions of the firm and the use of financial metrics for assessing the profitability of these divisions.
# gers: None
# repeatable: false
# grading: GSB Letter Graded
# unitsMin: 2
# unitsMax: 2
# learningObjectives: None
# sections: [OrderedDict([(u'classId', u'34260'), (u'term', u'2017-2018 Spring'), (u'termId', u'1186'), (u'subject', u'ACCT'), (u'code', u'212'), (u'units', u'2'), (u'sectionNumber', u'02'), (u'component', u'CAS'), (u'numEnrolled', u'0'), (u'maxEnrolled', u'72'), (u'numWaitlist', u'0'), (u'maxWaitlist', u'99'), (u'enrollStatus', u'Open'), (u'addConsent', u'N'), (u'dropConsent', u'N'), (u'courseId', u'201624'), (u'schedules', [OrderedDict([(u'startDate', u'May 7, 2018'), (u'endDate', u'Jun 5, 2018'), (u'startTime', None), (u'endTime', None), (u'location', None), (u'days', None), (u'instructors', [OrderedDict([(u'name', u'Marinovic, I.'), (u'firstName', u'Ivan'), (u'middleName', None), (u'lastName', u'Marinovic'), (u'sunet', u'imvial'), (u'role', u'PI')])])])]), (u'currentClassSize', u'0'), (u'maxClassSize', u'72'), (u'currentWaitlistSize', u'0'), (u'maxWaitlistSize', u'99'), (u'notes', u'Case and Problem Discussion. P/F Not Allowed. Open to MBA1 students. Enrolled + waitlisted must attend or be dropped. Final 40% Participation 30% Projects/Papers 30%. Take-home Final. 3 Group Projects/Papers.'), (u'attributes', OrderedDict([(u'attribute', [OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APFA'), (u'value', u'NTALLOW'), (u'description', u'P/F Not Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AAPP'), (u'value', u'MB1'), (u'description', u'Open to MBA1 students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AATT'), (u'value', u'MANDWAITL'), (u'description', u'Enrolled + waitlisted must attend or be dropped.'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AGRA'), (u'value', u'F40C30P30'), (u'description', u'Final 40% Participation 30% Projects/Papers 30%'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AEXA'), (u'value', u'TKHFN'), (u'description', u'Take-home Final'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APPR'), (u'value', u'3GRPP'), (u'description', u'3 Group Projects/Papers'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])])]))]), OrderedDict([(u'classId', u'34261'), (u'term', u'2017-2018 Spring'), (u'termId', u'1186'), (u'subject', u'ACCT'), (u'code', u'212'), (u'units', u'2'), (u'sectionNumber', u'03'), (u'component', u'CAS'), (u'numEnrolled', u'0'), (u'maxEnrolled', u'72'), (u'numWaitlist', u'0'), (u'maxWaitlist', u'99'), (u'enrollStatus', u'Open'), (u'addConsent', u'N'), (u'dropConsent', u'N'), (u'courseId', u'201624'), (u'schedules', [OrderedDict([(u'startDate', u'May 7, 2018'), (u'endDate', u'Jun 5, 2018'), (u'startTime', None), (u'endTime', None), (u'location', None), (u'days', None), (u'instructors', [OrderedDict([(u'name', u'Marinovic, I.'), (u'firstName', u'Ivan'), (u'middleName', None), (u'lastName', u'Marinovic'), (u'sunet', u'imvial'), (u'role', u'PI')])])])]), (u'currentClassSize', u'0'), (u'maxClassSize', u'72'), (u'currentWaitlistSize', u'0'), (u'maxWaitlistSize', u'99'), (u'notes', u'Case and Problem Discussion. P/F Not Allowed. Open to MBA1 students. Enrolled + waitlisted must attend or be dropped. Final 40% Participation 30% Projects/Papers 30%. Take-home Final. 3 Group Projects/Papers.'), (u'attributes', OrderedDict([(u'attribute', [OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APFA'), (u'value', u'NTALLOW'), (u'description', u'P/F Not Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AAPP'), (u'value', u'MB1'), (u'description', u'Open to MBA1 students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AATT'), (u'value', u'MANDW ...
# administrativeInformation: OrderedDict([(u'courseId', u'201624'), (u'effectiveStatus', u'A'), (u'offerNumber', u'1'), (u'academicGroup', u'GSB'), (u'academicOrganization', u'GSB'), (u'academicCareer', u'GSB'), (u'finalExamFlag', u'N'), (u'catalogPrint', u'Y'), (u'schedulePrint', u'Y'), (u'maxUnitsRepeat', u'2'), (u'maxTimesRepeat', u'1')])
# attributes: [OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APFA'), (u'value', u'NTALLOW'), (u'description', u'P/F Not Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AAPP'), (u'value', u'MB1'), (u'description', u'Open to MBA1 students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AATT'), (u'value', u'MANDWAITL'), (u'description', u'Enrolled + waitlisted must attend or be dropped.'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AGRA'), (u'value', u'F40C30P30'), (u'description', u'Final 40% Participation 30% Projects/Papers 30%'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AEXA'), (u'value', u'TKHFN'), (u'description', u'Take-home Final'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APPR'), (u'value', u'3GRPP'), (u'description', u'3 Group Projects/Papers'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])]
# tags: [OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')]), OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')]), OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])]
# ***
# year: 2017-2018
# subject: ACCT
# code: 213
# title: Financial Accounting - Accelerated
# description: This course develops students' ability to read, understand, and use corporate financial statements. The course is oriented toward the user of financial accounting data (rather than the preparer) and emphasizes the reconstruction and interpretation of economic events from published accounting reports. The course is geared toward students with some familiarity in dealing with financial statement information and allows for deeper coverage and discussion in class.
# gers: None
# repeatable: false
# grading: GSB Letter Graded
# unitsMin: 4
# unitsMax: 4
# learningObjectives: None
# sections: [OrderedDict([(u'classId', u'29917'), (u'term', u'2017-2018 Autumn'), (u'termId', u'1182'), (u'subject', u'ACCT'), (u'code', u'213'), (u'units', u'4'), (u'sectionNumber', u'01'), (u'component', u'CAS'), (u'numEnrolled', u'50'), (u'maxEnrolled', u'60'), (u'numWaitlist', u'0'), (u'maxWaitlist', u'0'), (u'enrollStatus', u'Open'), (u'addConsent', u'D'), (u'dropConsent', u'D'), (u'courseId', u'205579'), (u'schedules', [OrderedDict([(u'startDate', u'Sep 25, 2017'), (u'endDate', u'Dec 8, 2017'), (u'startTime', u'8:00:00 AM'), (u'endTime', u'9:45:00 AM'), (u'location', u'GSB Patterson 107'), (u'days', u'Monday\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\tThursday'), (u'instructors', [OrderedDict([(u'name', u'Kasznik, R.'), (u'firstName', u'Ron'), (u'middleName', None), (u'lastName', u'Kasznik'), (u'sunet', u'fkasznik'), (u'role', u'PI')]), OrderedDict([(u'name', u'Wells, K.'), (u'firstName', u'Kelly'), (u'middleName', None), (u'lastName', u'Wells'), (u'sunet', u'kcwells7'), (u'role', u'GP')])])])]), (u'currentClassSize', u'50'), (u'maxClassSize', u'60'), (u'currentWaitlistSize', u'0'), (u'maxWaitlistSize', u'0'), (u'notes', u"Case and Problem Discussion. P/F Not Allowed. Open to MBA1 students. Final 40% Midterm 30% Participat'n 15% Proj/Pap 15. In-class Midterm and Final. Mandatory attendance. Absences impact grade. Not Open to Non-GSB Students."), (u'attributes', OrderedDict([(u'attribute', [OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APFA'), (u'value', u'NTALLOW'), (u'description', u'P/F Not Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AAPP'), (u'value', u'MB1'), (u'description', u'Open to MBA1 students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AGRA'), (u'value', u'F40M30C15P'), (u'description', u"Final 40% Midterm 30% Participat'n 15% Proj/Pap 15"), (u'catalogPrint', u'true'), (u'schedulePrint', u'false')]), OrderedDict([(u'name', u'AEXA'), (u'value', u'INCMD&FN'), (u'description', u'In-class Midterm and Final'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AATT'), (u'value', u'MANDATORY'), (u'description', u'Mandatory attendance. Absences impact grade.'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'ANON'), (u'value', u'NOTOPEN'), (u'description', u'Not Open to Non-GSB Students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])])]))]), OrderedDict([(u'classId', u'29918'), (u'term', u'2017-2018 Autumn'), (u'termId', u'1182'), (u'subject', u'ACCT'), (u'code', u'213'), (u'units', u'4'), (u'sectionNumber', u'02'), (u'component', u'CAS'), (u'numEnrolled', u'42'), (u'maxEnrolled', u'60'), (u'numWaitlist', u'0'), (u'maxWaitlist', u'0'), (u'enrollStatus', u'Open'), (u'addConsent', u'D'), (u'dropConsent', u'D'), (u'courseId', u'205579'), (u'schedules', [OrderedDict([(u'startDate', u'Sep 25, 2017'), (u'endDate', u'Dec 8, 2017'), (u'startTime', u'10:00:00 AM'), (u'endTime', u'11:45:00 AM'), (u'location', u'GSB Patterson 107'), (u'days', u'Monday\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\tThursday'), (u'instructors', [OrderedDict([(u'name', u'Kasznik, R.'), (u'firstName', u'Ron'), (u'middleName', None), (u'lastName', u'Kasznik'), (u'sunet', u'fkasznik'), (u'role', u'PI')]), OrderedDict([(u'name', u'Wells, K.'), (u'firstName', u'Kelly'), (u'middleName', None), (u'lastName', u'Wells'), (u'sunet', u'kcwells7'), (u'role', u'GP')])])])]), (u'currentClassSize', u'42'), (u'maxClassSize', u'60'), (u'currentWaitlistSize', u'0'), (u'maxWaitlistSize', u'0'), (u'notes', u"Case and Problem Discussion. P/F Not Allowed. Open to MBA1 students. Final 40% Midterm 30% Participat'n 15% Proj/Pap 15. In-class Midterm and Final. Mandatory attendance. Absences impact grade. Not  ...
# administrativeInformation: OrderedDict([(u'courseId', u'205579'), (u'effectiveStatus', u'A'), (u'offerNumber', u'1'), (u'academicGroup', u'GSB'), (u'academicOrganization', u'GSB'), (u'academicCareer', u'GSB'), (u'finalExamFlag', u'N'), (u'catalogPrint', u'Y'), (u'schedulePrint', u'Y'), (u'maxUnitsRepeat', u'4'), (u'maxTimesRepeat', u'1')])
# attributes: [OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APFA'), (u'value', u'NTALLOW'), (u'description', u'P/F Not Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AAPP'), (u'value', u'MB1'), (u'description', u'Open to MBA1 students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AGRA'), (u'value', u'F40M30C15P'), (u'description', u"Final 40% Midterm 30% Participat'n 15% Proj/Pap 15"), (u'catalogPrint', u'true'), (u'schedulePrint', u'false')]), OrderedDict([(u'name', u'AEXA'), (u'value', u'INCMD&FN'), (u'description', u'In-class Midterm and Final'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AATT'), (u'value', u'MANDATORY'), (u'description', u'Mandatory attendance. Absences impact grade.'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'ANON'), (u'value', u'NOTOPEN'), (u'description', u'Not Open to Non-GSB Students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])]
# tags: [OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')]), OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')]), OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])]
# ***
# year: 2017-2018
# subject: ACCT
# code: 219
# title: MSx: Accounting
# description: A characteristic of business is the extensive use of accounting data. The financial accounting course has the general objective of developing students' understanding of the nature, scope, and limitations of accounting information. To achieve this objective the course attempts to: (1) develop students' understanding of the conceptual accounting framework, including the objectives of financial reporting, and (2) develop students' ability to understand and critically evaluate the financial disclosures made by corporations. An issue of particular interest will be the managerial incentive aspects of accounting information and disclosures.
# gers: None
# repeatable: false
# grading: GSB Letter Graded
# unitsMin: 3
# unitsMax: 3
# learningObjectives: None
# sections: None
# administrativeInformation: OrderedDict([(u'courseId', u'100740'), (u'effectiveStatus', u'A'), (u'offerNumber', u'1'), (u'academicGroup', u'GSB'), (u'academicOrganization', u'GSB'), (u'academicCareer', u'GSB'), (u'finalExamFlag', u'N'), (u'catalogPrint', u'Y'), (u'schedulePrint', u'Y'), (u'maxUnitsRepeat', u'3'), (u'maxTimesRepeat', u'1')])
# attributes: [OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APFA'), (u'value', u'NTALLOW'), (u'description', u'P/F Not Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AAPP'), (u'value', u'SLN'), (u'description', u'Open to MSx students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AEXA'), (u'value', u'INCMD&FN'), (u'description', u'In-class Midterm and Final'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AATT'), (u'value', u'MANDATORY'), (u'description', u'Mandatory attendance. Absences impact grade.'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'ANON'), (u'value', u'NOTOPEN'), (u'description', u'Not Open to Non-GSB Students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AGRA'), (u'value', u'F40M30C15H'), (u'description', u"Final 40% Midterm 30% Participat'n 15% HW 15"), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])]
# tags: [OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')]), OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')]), OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])]
# ***
# year: 2017-2018
# subject: ACCT
# code: 311
# title: Global Financial Reporting
# description: This course is designed to enhance students' understanding of current financial reporting issues through a detailed analysis and comparison of U.S. and International Financial Reporting Standards. The course will cover the development of accounting standards, implementation of these standards, and how to interpret output from these standards. The course highlights intermediate and advanced financial reporting topics including fair value accounting, asset securitization, consolidation including special purpose entities, foreign currency translation, derivatives and hedging, leases, revenue recognition, pensions, and equity compensation. The course also focuses on evaluating emerging financial reporting issues such as proposed financial reporting standards put forth by U.S. or international standard setting bodies. This course should help students better understand the environment governing global financial reporting and how firms develop financial statement information within this environment.
# gers: None
# repeatable: false
# grading: GSB Letter Graded
# unitsMin: 4
# unitsMax: 4
# learningObjectives: None
# sections: [OrderedDict([(u'classId', u'29924'), (u'term', u'2017-2018 Autumn'), (u'termId', u'1182'), (u'subject', u'ACCT'), (u'code', u'311'), (u'units', u'4'), (u'sectionNumber', u'02'), (u'component', u'CAS'), (u'numEnrolled', u'58'), (u'maxEnrolled', u'72'), (u'numWaitlist', u'0'), (u'maxWaitlist', u'0'), (u'enrollStatus', u'Open'), (u'addConsent', u'D'), (u'dropConsent', u'D'), (u'courseId', u'100861'), (u'schedules', [OrderedDict([(u'startDate', u'Sep 25, 2017'), (u'endDate', u'Dec 8, 2017'), (u'startTime', u'10:00:00 AM'), (u'endTime', u'11:45:00 AM'), (u'location', u'GSB McClelland 109'), (u'days', u'Monday\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\tThursday'), (u'instructors', [OrderedDict([(u'name', u'Blankespoor, E.'), (u'firstName', u'Elizabeth'), (u'middleName', None), (u'lastName', u'Blankespoor'), (u'sunet', u'blankbe'), (u'role', u'PI')]), OrderedDict([(u'name', u'Bligh, S.'), (u'firstName', u'Shauna'), (u'middleName', None), (u'lastName', u'Bligh'), (u'sunet', u'sbligh'), (u'role', u'GP')]), OrderedDict([(u'name', u'Siegrist, K.'), (u'firstName', u'Kirstin'), (u'middleName', None), (u'lastName', u'Siegrist'), (u'sunet', u'kaks125'), (u'role', u'GP')])])])]), (u'currentClassSize', u'58'), (u'maxClassSize', u'72'), (u'currentWaitlistSize', u'0'), (u'maxWaitlistSize', u'0'), (u'notes', u'Case and Problem Discussion. P/F Not Allowed. Open to MBA1 students. 1 Group Project/Paper. Take-home Final. Mandatory attendance. Absences impact grade. Not Open to Non-GSB Students. Final 35% Par 20% Proj/paper 20%,25% Assignments.'), (u'attributes', OrderedDict([(u'attribute', [OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APFA'), (u'value', u'NTALLOW'), (u'description', u'P/F Not Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AAPP'), (u'value', u'MB1'), (u'description', u'Open to MBA1 students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APPR'), (u'value', u'1GRPP'), (u'description', u'1 Group Project/Paper'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AEXA'), (u'value', u'TKHFN'), (u'description', u'Take-home Final'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AATT'), (u'value', u'MANDATORY'), (u'description', u'Mandatory attendance. Absences impact grade.'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'ANON'), (u'value', u'NOTOPEN'), (u'description', u'Not Open to Non-GSB Students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AGRA'), (u'value', u'F35C20P20X'), (u'description', u'Final 35% Par 20% Proj/paper 20%,25% Assignments'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])])]))]), OrderedDict([(u'classId', u'29923'), (u'term', u'2017-2018 Autumn'), (u'termId', u'1182'), (u'subject', u'ACCT'), (u'code', u'311'), (u'units', u'4'), (u'sectionNumber', u'01'), (u'component', u'CAS'), (u'numEnrolled', u'69'), (u'maxEnrolled', u'72'), (u'numWaitlist', u'0'), (u'maxWaitlist', u'0'), (u'enrollStatus', u'Open'), (u'addConsent', u'D'), (u'dropConsent', u'D'), (u'courseId', u'100861'), (u'schedules', [OrderedDict([(u'startDate', u'Sep 25, 2017'), (u'endDate', u'Dec 8, 2017'), (u'startTime', u'8:00:00 AM'), (u'endTime', u'9:45:00 AM'), (u'location', u'GSB McClelland 109'), (u'days', u'Monday\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\tThursday'), (u'instructors', [OrderedDict([(u'name', u'Blankespoor, E.'), (u'firstName', u'Elizabeth'), (u'middleName', None), (u'lastName', u'Blankespoor'), (u'sunet', u'blankbe'), (u'role', u'PI')]), OrderedDict([(u'name', u'Bligh, S.'), (u'firstName', u'Shauna'), (u'middleName', None), (u'lastName', u'Bligh'), (u'sunet', u'sbligh'), (u'role', u' ...
# administrativeInformation: OrderedDict([(u'courseId', u'100861'), (u'effectiveStatus', u'A'), (u'offerNumber', u'1'), (u'academicGroup', u'GSB'), (u'academicOrganization', u'GSB'), (u'academicCareer', u'GSB'), (u'finalExamFlag', u'N'), (u'catalogPrint', u'Y'), (u'schedulePrint', u'Y'), (u'maxUnitsRepeat', u'4'), (u'maxTimesRepeat', u'1')])
# attributes: [OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APFA'), (u'value', u'NTALLOW'), (u'description', u'P/F Not Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AAPP'), (u'value', u'MB1'), (u'description', u'Open to MBA1 students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APPR'), (u'value', u'1GRPP'), (u'description', u'1 Group Project/Paper'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AEXA'), (u'value', u'TKHFN'), (u'description', u'Take-home Final'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AATT'), (u'value', u'MANDATORY'), (u'description', u'Mandatory attendance. Absences impact grade.'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'ANON'), (u'value', u'NOTOPEN'), (u'description', u'Not Open to Non-GSB Students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AGRA'), (u'value', u'F35C20P20X'), (u'description', u'Final 35% Par 20% Proj/paper 20%,25% Assignments'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])]
# tags: [OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')]), OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')]), OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])]
# ***
# year: 2017-2018
# subject: ACCT
# code: 313
# title: Accounting-Based Valuation
# description: This course is designed to develop students' ability to interpret and use financial accounting information in an equity valuation context. The perspective taken is that of an outsider relying on publicly available financial information for investment purposes.  The course relies heavily upon financial statement analysis tools and the residual income framework for equity valuation.  Through lectures, in-depth case studies, and real-time exercises, the first half of the course covers traditional financial statement analysis-based tools for critically analyzing and assessing a firm's current financial performance and economic condition, including ratio analysis, accounting quality analysis and financial distress / bankruptcy prediction models.  The second half of the course introduces the accounting-based valuation framework and develops the link between financial statement analysis, forecasting and equity valuation.  The capstone to the course is the completion of a comprehensive, real-time valuation of a publicly traded firm (or registered IPO candidate).  The course is structured for students to gain a deeper understanding of the economic pressures behind the valuation creation and valuation process, and will be useful to those students who anticipate making investment or credit decisions at least partially based on historical and prospective financial statement information.
# gers: None
# repeatable: false
# grading: GSB Student Option LTR/PF
# unitsMin: 3
# unitsMax: 3
# learningObjectives: None
# sections: [OrderedDict([(u'classId', u'31416'), (u'term', u'2017-2018 Winter'), (u'termId', u'1184'), (u'subject', u'ACCT'), (u'code', u'313'), (u'units', u'3'), (u'sectionNumber', u'01'), (u'component', u'CAS'), (u'numEnrolled', u'0'), (u'maxEnrolled', u'65'), (u'numWaitlist', u'0'), (u'maxWaitlist', u'99'), (u'enrollStatus', u'Open'), (u'addConsent', u'N'), (u'dropConsent', u'N'), (u'courseId', u'207785'), (u'schedules', [OrderedDict([(u'startDate', u'Jan 8, 2018'), (u'endDate', u'Mar 16, 2018'), (u'startTime', u'1:30:00 PM'), (u'endTime', u'2:50:00 PM'), (u'location', None), (u'days', u'Tuesday\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\tThursday'), (u'instructors', [OrderedDict([(u'name', u'Piotroski, J.'), (u'firstName', u'Joseph'), (u'middleName', u'D'), (u'lastName', u'Piotroski'), (u'sunet', u'jpiotros'), (u'role', u'PI')])])])]), (u'currentClassSize', u'0'), (u'maxClassSize', u'65'), (u'currentWaitlistSize', u'0'), (u'maxWaitlistSize', u'99'), (u'notes', u'Students should have some familiarity with financial accounting and basic DCF valuation models. Please review the syllabus and/or contact the instructor with questions about your ability to handle the course. GSB PhD students need instructor permission. Case and Problem Discussion. 1 Group Project/Paper. Open to MBA and MSx students. Midterm 35% Participation 20% Projects/Papers 45%. Take-home Midterm. Mandatory attendance. Absences impact grade. P/F Allowed. Non-GSB students: See gsb.stanford.edu/NonGSBReg.'), (u'attributes', OrderedDict([(u'attribute', [OrderedDict([(u'name', u'AAPP'), (u'value', u'PRMPHD'), (u'description', u'GSB PhD students need instructor permission'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APPR'), (u'value', u'1GRPP'), (u'description', u'1 Group Project/Paper'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AAPP'), (u'value', u'MBASLN'), (u'description', u'Open to MBA and MSx students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AGRA'), (u'value', u'M35C20P45'), (u'description', u'Midterm 35% Participation 20% Projects/Papers 45%'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AEXA'), (u'value', u'TKHMD'), (u'description', u'Take-home Midterm'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AATT'), (u'value', u'MANDATORY'), (u'description', u'Mandatory attendance. Absences impact grade.'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APFA'), (u'value', u'ALLOW'), (u'description', u'P/F Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'ANON'), (u'value', u'PERMISSION'), (u'description', u'Non-GSB students: See gsb.stanford.edu/NonGSBReg.'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])])]))]), OrderedDict([(u'classId', u'31418'), (u'term', u'2017-2018 Winter'), (u'termId', u'1184'), (u'subject', u'ACCT'), (u'code', u'313'), (u'units', u'3'), (u'sectionNumber', u'02'), (u'component', u'CAS'), (u'numEnrolled', u'0'), (u'maxEnrolled', u'65'), (u'numWaitlist', u'0'), (u'maxWaitlist', u'0'), (u'enrollStatus', u'Open'), (u'addConsent', u'N'), (u'dropConsent', u'N'), (u'courseId', u'207785'), (u'schedules', [OrderedDict([(u'startDate', u'Jan 8, 2018'), (u'endDate', u'Mar 16, 2018'), (u'startTime', u'3:00:00 PM'), (u'endTime', u'4:20:00 PM'), (u'location', None), (u'days', u'Tuesday\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\tThursday'), (u'instructors', [OrderedDict([(u'name', u'Piotroski, J.'), (u'firstName', u'Joseph'), (u'middleName', u'D'), (u'lastName', u'Piotroski'), (u'sunet', u'jpiotros'), (u'role', u'PI')])])])]), (u'currentClassSize', u'0'), (u'maxClassSize', u'65'), (u'currentW ...
# administrativeInformation: OrderedDict([(u'courseId', u'207785'), (u'effectiveStatus', u'A'), (u'offerNumber', u'1'), (u'academicGroup', u'GSB'), (u'academicOrganization', u'GSB'), (u'academicCareer', u'GSB'), (u'finalExamFlag', u'N'), (u'catalogPrint', u'Y'), (u'schedulePrint', u'Y'), (u'maxUnitsRepeat', u'3'), (u'maxTimesRepeat', u'1')])
# attributes: [OrderedDict([(u'name', u'AAPP'), (u'value', u'PRMPHD'), (u'description', u'GSB PhD students need instructor permission'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APPR'), (u'value', u'1GRPP'), (u'description', u'1 Group Project/Paper'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AAPP'), (u'value', u'MBASLN'), (u'description', u'Open to MBA and MSx students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AGRA'), (u'value', u'M35C20P45'), (u'description', u'Midterm 35% Participation 20% Projects/Papers 45%'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AEXA'), (u'value', u'TKHMD'), (u'description', u'Take-home Midterm'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'AATT'), (u'value', u'MANDATORY'), (u'description', u'Mandatory attendance. Absences impact grade.'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'APFA'), (u'value', u'ALLOW'), (u'description', u'P/F Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')]), OrderedDict([(u'name', u'ANON'), (u'value', u'PERMISSION'), (u'description', u'Non-GSB students: See gsb.stanford.edu/NonGSBReg.'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])]
# tags: [OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')]), OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')]), OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])]
# ***

# %%
# checking which of the sometimes null fields are worth keeping
# throw out learningObj, too many null 

for j in ['learningObjectives', 'attributes', 'sections', 'tags']:
    y, n = 0, 0
    for i, course in enumerate(a):
        x = course[j]
        if isinstance(x, list):
            y+=1
        else:
            n+=1
    print("{}, {}".format(y, n))
# Out:
# 2393, 12447
# 14327, 513
# 8624, 6216
# 12839, 2001

# %%
#bleh lists/dicts have nested dicts within..

for j in ['attributes', 'sections', 'tags', 'administrativeInformation']:
    for i, course in enumerate(a):
        x = course[j]
        if isinstance(x, list):
            for k, v in x[0].items():
                 print "{}: {}".format(k, v)
            print("-----")
            for k, v in x[0].items():
                 print "{}: {}".format(k, type(v))
            print("****")
            break
        if isinstance(x, OrderedDict):
            for k, v in x.items():
                print "{}: {}".format(k, v)
            for k, v in x.items():
                print "{}: {}".format(k, type(v))
            print("****")
            break
# Out:
# name: NQTR
# value: NOTTHIS
# description: not given this year
# catalogPrint: true
# schedulePrint: false
# -----
# name: <type 'unicode'>
# value: <type 'unicode'>
# description: <type 'unicode'>
# catalogPrint: <type 'unicode'>
# schedulePrint: <type 'unicode'>
# ****
# classId: 8528
# term: 2017-2018 Autumn
# termId: 1182
# subject: AA
# code: 100
# units: 3
# sectionNumber: 01
# component: LEC
# numEnrolled: 38
# maxEnrolled: 80
# numWaitlist: 0
# maxWaitlist: 0
# enrollStatus: Open
# addConsent: N
# dropConsent: N
# courseId: 103093
# schedules: [OrderedDict([(u'startDate', u'Sep 25, 2017'), (u'endDate', u'Dec 8, 2017'), (u'startTime', u'1:30:00 PM'), (u'endTime', u'2:50:00 PM'), (u'location', u'200-030'), (u'days', u'Monday\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\tWednesday'), (u'instructors', [OrderedDict([(u'name', u'Kroo, I.'), (u'firstName', u'Ilan'), (u'middleName', u'M'), (u'lastName', u'Kroo'), (u'sunet', u'kroo'), (u'role', u'PI')]), OrderedDict([(u'name', u'Hockman, B.'), (u'firstName', u'Ben'), (u'middleName', None), (u'lastName', u'Hockman'), (u'sunet', u'bhockman'), (u'role', u'TA')]), OrderedDict([(u'name', u'Coates, A.'), (u'firstName', u'Ashley'), (u'middleName', u'Michelle'), (u'lastName', u'Coates'), (u'sunet', u'amcoates'), (u'role', u'TA')]), OrderedDict([(u'name', u'Hinojosa, M.'), (u'firstName', u'Marco'), (u'middleName', u'Antonio'), (u'lastName', u'Hinojosa'), (u'sunet', u'mah5h7'), (u'role', u'TA')]), OrderedDict([(u'name', u'Pavone, M.'), (u'firstName', u'Marco'), (u'middleName', None), (u'lastName', u'Pavone'), (u'sunet', u'pavone'), (u'role', u'PI')])])])]
# currentClassSize: 38
# maxClassSize: 80
# currentWaitlistSize: 0
# maxWaitlistSize: 0
# notes: None
# attributes: OrderedDict([(u'attribute', OrderedDict([(u'name', u'NQTR'), (u'value', u'AUT'), (u'description', u'Autumn'), (u'catalogPrint', u'true'), (u'schedulePrint', u'false')]))])
# -----
# classId: <type 'unicode'>
# term: <type 'unicode'>
# termId: <type 'unicode'>
# subject: <type 'unicode'>
# code: <type 'unicode'>
# units: <type 'unicode'>
# sectionNumber: <type 'unicode'>
# component: <type 'unicode'>
# numEnrolled: <type 'unicode'>
# maxEnrolled: <type 'unicode'>
# numWaitlist: <type 'unicode'>
# maxWaitlist: <type 'unicode'>
# enrollStatus: <type 'unicode'>
# addConsent: <type 'unicode'>
# dropConsent: <type 'unicode'>
# courseId: <type 'unicode'>
# schedules: <type 'list'>
# currentClassSize: <type 'unicode'>
# maxClassSize: <type 'unicode'>
# currentWaitlistSize: <type 'unicode'>
# maxWaitlistSize: <type 'unicode'>
# notes: <type 'NoneType'>
# attributes: <class 'collections.OrderedDict'>
# ****
# organization: EDUC
# name: alluniversity
# -----
# organization: <type 'unicode'>
# name: <type 'unicode'>
# ****
# courseId: 217539
# effectiveStatus: A
# offerNumber: 1
# academicGroup: ENGR
# academicOrganization: AEROASTRO
# academicCareer: UG
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 1
# maxTimesRepeat: 1
# courseId: <type 'unicode'>
# effectiveStatus: <type 'unicode'>
# offerNumber: <type 'unicode'>
# academicGroup: <type 'unicode'>
# academicOrganization: <type 'unicode'>
# academicCareer: <type 'unicode'>
# finalExamFlag: <type 'unicode'>
# catalogPrint: <type 'unicode'>
# schedulePrint: <type 'unicode'>
# maxUnitsRepeat: <type 'unicode'>
# maxTimesRepeat: <type 'unicode'>
# ****

# %%
# admin analysis
# keep finalExamFlag and academicCareer 

admin_keys = [u'courseId', u'effectiveStatus', u'offerNumber', u'academicGroup', u'academicOrganization', u'academicCareer', u'finalExamFlag', u'catalogPrint', u'schedulePrint', u'maxUnitsRepeat', u'maxTimesRepeat']

for i, course in enumerate(a):
    if i < 70:
        continue
    if i > 100:
        break
    print(i)
    print(course['title'])
    x = course['administrativeInformation'] 
    if x: # if dict, then always a dict with keys admin_keys 
        if x.keys() != admin_keys:
            print("!")
            break
        for k, v in x.items():
            print "{}: {}".format(k, v)
        print("****")
# Out:
# 70
# Seminar in Guidance, Navigation, and Control
# courseId: 103253
# effectiveStatus: A
# offerNumber: 1
# academicGroup: ENGR
# academicOrganization: AEROASTRO
# academicCareer: GR
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 999
# maxTimesRepeat: 99
# ****
# 71
# Engineer Thesis
# courseId: 103259
# effectiveStatus: A
# offerNumber: 1
# academicGroup: ENGR
# academicOrganization: AEROASTRO
# academicCareer: GR
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 999
# maxTimesRepeat: 99
# ****
# 72
# Ph.D. Dissertation
# courseId: 103260
# effectiveStatus: A
# offerNumber: 1
# academicGroup: ENGR
# academicOrganization: AEROASTRO
# academicCareer: GR
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 999
# maxTimesRepeat: 99
# ****
# 73
# TGR Engineer Thesis
# courseId: 103262
# effectiveStatus: A
# offerNumber: 1
# academicGroup: ENGR
# academicOrganization: AEROASTRO
# academicCareer: GR
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 999
# maxTimesRepeat: 99
# ****
# 74
# TGR Ph.D. Dissertation
# courseId: 103263
# effectiveStatus: A
# offerNumber: 1
# academicGroup: ENGR
# academicOrganization: AEROASTRO
# academicCareer: GR
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 999
# maxTimesRepeat: 99
# ****
# 75
# Financial Accounting
# courseId: 100734
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 4
# maxTimesRepeat: 1
# ****
# 76
# Managerial Accounting: Base
# courseId: 201624
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 2
# maxTimesRepeat: 1
# ****
# 77
# Financial Accounting - Accelerated
# courseId: 205579
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 4
# maxTimesRepeat: 1
# ****
# 78
# MSx: Accounting
# courseId: 100740
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 3
# maxTimesRepeat: 1
# ****
# 79
# Global Financial Reporting
# courseId: 100861
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 4
# maxTimesRepeat: 1
# ****
# 80
# Accounting-Based Valuation
# courseId: 207785
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 3
# maxTimesRepeat: 1
# ****
# 81
# Managerial Accounting: Performance Measurement, Compensation, and Governance
# courseId: 207976
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 3
# maxTimesRepeat: 1
# ****
# 82
# Mergers and Acquisitions
# courseId: 210033
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 3
# maxTimesRepeat: 1
# ****
# 83
# Taxes and Business Strategy
# courseId: 216572
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 3
# maxTimesRepeat: 1
# ****
# 84
# Alphanomics: Informational Arbitrage in Equity Markets
# courseId: 210147
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 4
# maxTimesRepeat: 1
# ****
# 85
# Analysis and Valuation for Event-Driven Investing
# courseId: 210318
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 3
# maxTimesRepeat: 1
# ****
# 86
# Analysis and Valuation of Emerging Market Firms
# courseId: 207840
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 2
# maxTimesRepeat: 1
# ****
# 87
# Board Governance
# courseId: 213470
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 2
# maxTimesRepeat: 1
# ****
# 88
# Individual Taxes and Financial Planning
# courseId: 218629
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 2
# maxTimesRepeat: 1
# ****
# 89
# Corporate Taxes and Business Strategy
# courseId: 219724
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 2
# maxTimesRepeat: 1
# ****
# 90
# Financial Reporting and Management Control
# courseId: 202649
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 3
# maxTimesRepeat: 1
# ****
# 91
# Seminar in Empirical Accounting Research
# courseId: 218932
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 3
# maxTimesRepeat: 1
# ****
# 92
# Seminar in Empirical Accounting Research
# courseId: 101305
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 3
# maxTimesRepeat: 1
# ****
# 93
# Applications of Information Economics in Management and Accounting
# courseId: 101308
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 3
# maxTimesRepeat: 1
# ****
# 94
# Financial Reporting Seminar
# courseId: 101311
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 3
# maxTimesRepeat: 1
# ****
# 95
# Selected Topics in Empirical Accounting Research
# courseId: 211759
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 3
# maxTimesRepeat: 1
# ****
# 96
# Applications of Contract Theory in Accounting Research
# courseId: 208031
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 2
# maxTimesRepeat: 1
# ****
# 97
# Market Efficiency and Informational Arbitrage
# courseId: 216503
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 3
# maxTimesRepeat: 1
# ****
# 98
# Market Efficiency and Informational Arbitrage
# courseId: 218933
# effectiveStatus: A
# offerNumber: 1
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 3
# maxTimesRepeat: 1
# ****
# 99
# PhD Directed Reading (FINANCE 691, GSBGEN 691, HRMGT 691, MGTECON 691, MKTG 691, OB 691, OIT 691, POLECON 691, STRAMGT 691)
# courseId: 101403
# effectiveStatus: A
# offerNumber: 2
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 999
# maxTimesRepeat: 99
# ****
# 100
# PhD Dissertation Research (FINANCE 692, GSBGEN 692, HRMGT 692, MGTECON 692, MKTG 692, OB 692, OIT 692, POLECON 692, STRAMGT 692)
# courseId: 101406
# effectiveStatus: A
# offerNumber: 2
# academicGroup: GSB
# academicOrganization: GSB
# academicCareer: GSB
# finalExamFlag: N
# catalogPrint: Y
# schedulePrint: Y
# maxUnitsRepeat: 999
# maxTimesRepeat: 99
# ****

# %%
# attributes analysis 

dict_type_keys = [u'name', u'value', u'description', u'catalogPrint', u'schedulePrint']

for i, course in enumerate(a):
    if i < 70:
        continue
    if i > 100:
        break
    #print(i)
    #print(course['title'])
    x = course['attributes'] 
    if x: 
        if isinstance(x, list): # list of dicts with keys dict_type_keys
            #print(len(x))
            if len(x) > 1:
                print(course['title'])
                print(x[0])
                print(x[1])
            print("******")
        else:
            print('shouldnt be another type')
            break
# Out:
# ******
# Engineer Thesis
# OrderedDict([(u'name', u'NQTR'), (u'value', u'SPR'), (u'description', u'Spring'), (u'catalogPrint', u'true'), (u'schedulePrint', u'false')])
# OrderedDict([(u'name', u'NQTR'), (u'value', u'WIN'), (u'description', u'Winter'), (u'catalogPrint', u'true'), (u'schedulePrint', u'false')])
# ******
# Ph.D. Dissertation
# OrderedDict([(u'name', u'NQTR'), (u'value', u'SPR'), (u'description', u'Spring'), (u'catalogPrint', u'true'), (u'schedulePrint', u'false')])
# OrderedDict([(u'name', u'NQTR'), (u'value', u'WIN'), (u'description', u'Winter'), (u'catalogPrint', u'true'), (u'schedulePrint', u'false')])
# ******
# TGR Engineer Thesis
# OrderedDict([(u'name', u'NQTR'), (u'value', u'SPR'), (u'description', u'Spring'), (u'catalogPrint', u'true'), (u'schedulePrint', u'false')])
# OrderedDict([(u'name', u'NQTR'), (u'value', u'WIN'), (u'description', u'Winter'), (u'catalogPrint', u'true'), (u'schedulePrint', u'false')])
# ******
# TGR Ph.D. Dissertation
# OrderedDict([(u'name', u'NQTR'), (u'value', u'SPR'), (u'description', u'Spring'), (u'catalogPrint', u'true'), (u'schedulePrint', u'false')])
# OrderedDict([(u'name', u'NQTR'), (u'value', u'WIN'), (u'description', u'Winter'), (u'catalogPrint', u'true'), (u'schedulePrint', u'false')])
# ******
# Financial Accounting
# OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'APFA'), (u'value', u'NTALLOW'), (u'description', u'P/F Not Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Managerial Accounting: Base
# OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'APFA'), (u'value', u'NTALLOW'), (u'description', u'P/F Not Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Financial Accounting - Accelerated
# OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'APFA'), (u'value', u'NTALLOW'), (u'description', u'P/F Not Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# MSx: Accounting
# OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'APFA'), (u'value', u'NTALLOW'), (u'description', u'P/F Not Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Global Financial Reporting
# OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'APFA'), (u'value', u'NTALLOW'), (u'description', u'P/F Not Allowed'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Accounting-Based Valuation
# OrderedDict([(u'name', u'AAPP'), (u'value', u'PRMPHD'), (u'description', u'GSB PhD students need instructor permission'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Managerial Accounting: Performance Measurement, Compensation, and Governance
# OrderedDict([(u'name', u'AEXA'), (u'value', u'NOEXAM'), (u'description', u'No Exam'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Mergers and Acquisitions
# OrderedDict([(u'name', u'AEXA'), (u'value', u'NOEXAM'), (u'description', u'No Exam'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Taxes and Business Strategy
# OrderedDict([(u'name', u'AEXA'), (u'value', u'NOEXAM'), (u'description', u'No Exam'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Alphanomics: Informational Arbitrage in Equity Markets
# OrderedDict([(u'name', u'AEXA'), (u'value', u'NOEXAM'), (u'description', u'No Exam'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Analysis and Valuation for Event-Driven Investing
# OrderedDict([(u'name', u'AEXA'), (u'value', u'NOEXAM'), (u'description', u'No Exam'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AGRA'), (u'value', u'C20P60X20'), (u'description', u'Participation 20% Projects/Papers 60% Other 20%'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Analysis and Valuation of Emerging Market Firms
# OrderedDict([(u'name', u'AEXA'), (u'value', u'NOEXAM'), (u'description', u'No Exam'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AAPP'), (u'value', u'PRMPHD'), (u'description', u'GSB PhD students need instructor permission'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Board Governance
# OrderedDict([(u'name', u'AGRA'), (u'value', u'C100'), (u'description', u'Participation 100%'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AEXA'), (u'value', u'NOEXAM'), (u'description', u'No Exam'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Individual Taxes and Financial Planning
# OrderedDict([(u'name', u'AEXA'), (u'value', u'NOEXAM'), (u'description', u'No Exam'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Corporate Taxes and Business Strategy
# OrderedDict([(u'name', u'AEXA'), (u'value', u'NOEXAM'), (u'description', u'No Exam'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AMOD'), (u'value', u'CASEPROB'), (u'description', u'Case and Problem Discussion'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Financial Reporting and Management Control
# OrderedDict([(u'name', u'AAPP'), (u'value', u'PHD'), (u'description', u'Open to GSB PhD students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AMOD'), (u'value', u'SEMINAR'), (u'description', u'Seminar'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Seminar in Empirical Accounting Research
# OrderedDict([(u'name', u'AEXA'), (u'value', u'NOEXAM'), (u'description', u'No Exam'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AAPP'), (u'value', u'PHD'), (u'description', u'Open to GSB PhD students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Seminar in Empirical Accounting Research
# OrderedDict([(u'name', u'AEXA'), (u'value', u'NOEXAM'), (u'description', u'No Exam'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AAPP'), (u'value', u'PHD'), (u'description', u'Open to GSB PhD students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Applications of Information Economics in Management and Accounting
# OrderedDict([(u'name', u'AAPP'), (u'value', u'PHD'), (u'description', u'Open to GSB PhD students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'ANON'), (u'value', u'OPEN'), (u'description', u'Non-GSB students: See gsb.stanford.edu/NonGSBReg.'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Financial Reporting Seminar
# OrderedDict([(u'name', u'AEXA'), (u'value', u'NOEXAM'), (u'description', u'No Exam'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AAPP'), (u'value', u'PHD'), (u'description', u'Open to GSB PhD students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Selected Topics in Empirical Accounting Research
# OrderedDict([(u'name', u'AEXA'), (u'value', u'NOEXAM'), (u'description', u'No Exam'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AGRA'), (u'value', u'C50P50'), (u'description', u'Participation 50% Projects/Papers 50%'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Applications of Contract Theory in Accounting Research
# OrderedDict([(u'name', u'AAPP'), (u'value', u'PHD'), (u'description', u'Open to GSB PhD students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AGRA'), (u'value', u'F60C40'), (u'description', u'Final 60% Participation 40%'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Market Efficiency and Informational Arbitrage
# OrderedDict([(u'name', u'AEXA'), (u'value', u'NOEXAM'), (u'description', u'No Exam'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AAPP'), (u'value', u'PHD'), (u'description', u'Open to GSB PhD students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******
# Market Efficiency and Informational Arbitrage
# OrderedDict([(u'name', u'AEXA'), (u'value', u'NOEXAM'), (u'description', u'No Exam'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# OrderedDict([(u'name', u'AAPP'), (u'value', u'PHD'), (u'description', u'Open to GSB PhD students'), (u'catalogPrint', u'true'), (u'schedulePrint', u'true')])
# ******

# %%
# sections analysis 

# len 23
dict_type_keys = [u'classId', u'term', u'termId', u'subject', u'code', u'units', u'sectionNumber', 
                  u'component', u'numEnrolled', u'maxEnrolled', u'numWaitlist', u'maxWaitlist', 
                  u'enrollStatus', u'addConsent', u'dropConsent', u'courseId', u'schedules', u'currentClassSize', 
                  u'maxClassSize', u'currentWaitlistSize', u'maxWaitlistSize', u'notes', u'attributes']

dict_type_values = [set() for i in range(23)]
# [set([<type 'unicode'>]), set([<type 'unicode'>]), set([<type 'unicode'>]), set([<type 'unicode'>]),
#  set([<type 'unicode'>]), set([<type 'unicode'>, <type 'NoneType'>]), set([<type 'unicode'>]),
#  set([<type 'unicode'>]), set([<type 'unicode'>]), set([<type 'unicode'>]), set([<type 'unicode'>]),
#  set([<type 'unicode'>]), set([<type 'unicode'>]), set([<type 'unicode'>]), set([<type 'unicode'>]),
#  set([<type 'unicode'>]), set([<type 'list'>]), set([<type 'unicode'>]), set([<type 'unicode'>]),
#  set([<type 'unicode'>]), set([<type 'unicode'>]), set([<type 'unicode'>, <type 'NoneType'>]),
#  set([<type 'list'>, <type 'NoneType'>])]

# len 7
schedule_type_keys = [u'startDate', u'endDate', u'startTime', u'endTime', u'location', u'days', u'instructors']
schedule_type_values = [set() for i in range(7)]
# startDate: set([<type 'unicode'>, <type 'NoneType'>])
# endDate: set([<type 'unicode'>, <type 'NoneType'>])
# startTime: set([<type 'unicode'>, <type 'NoneType'>])
# endTime: set([<type 'unicode'>, <type 'NoneType'>])
# location: set([<type 'unicode'>, <type 'NoneType'>])
# days: set([<type 'unicode'>, <type 'NoneType'>])
# instructors: set([<type 'list'>, <type 'NoneType'>])

for i, course in enumerate(a):
    if i < 85:
        continue
    if i > 95:
        break
    #print(i)
    #print(course['title'])
    x = course['sections'] 
    if x: 
        if isinstance(x, list): # list of dicts with keys dict_type_keys
            #get value types
#             for m in range(len(x)):
#                 for k, v in x[m].items():
#                     n = dict_type_keys.index(k)
#                     dict_type_values[n].add(type(v))


            #shows attributes more complete than notes!
#             for m in range(len(x)):
#                 if x[m]['notes']:
#                     if not x[m]['attributes']:
#                         print("list{}".format(1))
#                         break
#                 if x[m]['attributes']:
#                     if not x[m]['notes']:
#                         print("list{}".format(2))
#                         break

            #viewing example fields
#             print(len(x))
#             for k, v in x[0].items():
#                 print "{}: {}".format(k, v)
#             print("------")
#             for k, v in x[1].items():
#                 print "{}: {}".format(k, v)  
            
            #parsing schedules
#             for m, section in enumerate(x): 
#                 schedules = section['schedules'] # list
#                 for n, schedule in enumerate(schedules): 
#                     if schedule.keys()!= schedule_type_keys:
#                         print("!")
#                     for k, v in schedule.items():
#                         j = schedule_type_keys.index(k)
#                         schedule_type_values[j].add(type(v))
                                        
#                     startTime = schedule.get('startTime')
#                     endTime = schedule.get('endTime')
#                     location = schedule.get('location')
#                     days = schedule.get('days')
#                     if days:
#                         days = ",".join((schedule.get('days')).split())
#                     instructors_list = schedule.get('instructors')
#                     if instructors_list:
#                         instructors = []
#                         for m, instructor in enumerate(instructors_list):
#                             name = ""
#                             first = instructor.get('firstName')
#                             name = name + first if first else name
#                             mid = instructor.get('middleName')
#                             name = name + " " + mid if mid else name
#                             last = instructor.get('lastName')
#                             name = name + " " + last if last else name
#                             if name:
#                                 instructors.append(name)
                   
#                     if startTime or endTime or location or days or instructors:
#                         for k, v in schedule.items():
#                             print "{}: {}".format(k, v) 
#                         print(startTime)
#                         print(endTime)
#                         print(location)
#                         print(days)
#                         print(",".join(instructors))

            #parsing attributes
#             for m, section in enumerate(x): 
#                 if section['attributes'] and len(attributes) > 1:
#                     print(course['title'])
#                     for n, attribute in enumerate(attributes): 
#                         if n > 2:
#                             break
#                         for k, v in attribute.items():
#                             print "{}: {}".format(k, v) 
#                         print("-----")
#                 print("****")
#                 break

            for m, section in enumerate(x): 
                attributes = section['attributes'] # list
                print(course['title'])
                if section['attributes']:
                    agg = []
                    for n, attribute in enumerate(attributes):
                        if attribute['description']:
                            agg.append(attribute['description'])
                    if agg:
                        print(",".join(agg))
            print("-------")

        else:
            print('shouldnt be another type')
            break
    #print("******") 


# for i in range(len(dict_type_keys)):
#     print("{}: {}".format(dict_type_keys[i], dict_type_values[i]))
# print("--------------")

# for i in range(len(schedule_type_keys)):
#     print("{}: {}".format(schedule_type_keys[i], schedule_type_values[i]))
# print("--------------")
# Out:
# Analysis and Valuation for Event-Driven Investing
# No Exam,Participation 20% Projects/Papers 60% Other 20%,Enrolled + waitlisted must attend or be dropped.,P/F Allowed with Permission of Instructor,Seminar,Open to MBA and MSx students,Capacity limited to 30 Students,Non-GSB students: See gsb.stanford.edu/NonGSBReg.
# -------
# Analysis and Valuation of Emerging Market Firms
# No Exam,GSB PhD students need instructor permission,Case and Problem Discussion,1 Group Project/Paper,Participation 25% Project/Paper 75%,Mandatory attendance. Absences impact grade.,Open to MBA2 and MSx students,P/F Allowed,Non-GSB students: See gsb.stanford.edu/NonGSBReg.
# -------
# Board Governance
# Participation 100%,No Exam,Open to MBA2 students,GSB PhD students need instructor permission,Capacity limited to 40 students,Enrolled + waitlisted must attend or be dropped.,Seminar,P/F Allowed,Not Open to Non-GSB Students
# Board Governance
# Participation 100%,No Exam,Open to MBA2 students,GSB PhD students need instructor permission,Capacity limited to 40 students,Enrolled + waitlisted must attend or be dropped.,Seminar,P/F Allowed,Not Open to Non-GSB Students
# -------
# Individual Taxes and Financial Planning
# No Exam,Case and Problem Discussion,1 Group Project/Paper,Non-GSB students: See gsb.stanford.edu/NonGSBReg.,Capacity limited to 55 students,Open to MBA, MSx, and GSB PhD students,Mandatory attendance. Absences impact grade.,P/F Allowed,Participation 40% Projects/Papers 60%
# Individual Taxes and Financial Planning
# No Exam,Case and Problem Discussion,1 Group Project/Paper,Non-GSB students: See gsb.stanford.edu/NonGSBReg.,Capacity limited to 55 students,Open to MBA, MSx, and GSB PhD students,Mandatory attendance. Absences impact grade.,P/F Allowed,Participation 40% Projects/Papers 60%
# Individual Taxes and Financial Planning
# No Exam,Case and Problem Discussion,1 Group Project/Paper,Non-GSB students: See gsb.stanford.edu/NonGSBReg.,Capacity limited to 55 students,Open to MBA, MSx, and GSB PhD students,Mandatory attendance. Absences impact grade.,P/F Allowed,Participation 40% Projects/Papers 60%
# -------
# Corporate Taxes and Business Strategy
# No Exam,Case and Problem Discussion,1 Group Project/Paper,Non-GSB students: See gsb.stanford.edu/NonGSBReg.,Capacity limited to 55 students,Open to MBA, MSx, and GSB PhD students,Mandatory attendance. Absences impact grade.,P/F Allowed,Participation 40% Projects/Papers 60%
# Corporate Taxes and Business Strategy
# No Exam,Case and Problem Discussion,1 Group Project/Paper,Non-GSB students: See gsb.stanford.edu/NonGSBReg.,Capacity limited to 55 students,Open to MBA, MSx, and GSB PhD students,Mandatory attendance. Absences impact grade.,P/F Allowed,Participation 40% Projects/Papers 60%
# -------
# Seminar in Empirical Accounting Research
# No Exam,Open to GSB PhD students,P/F Allowed with Permission of Instructor,Seminar,Mandatory attendance. Absences impact grade.,MBA2 and MSx students need instructor permission,1 Group 3 Individual Projects/Papers,Participation 20% Proj/Papers30% Presentations 50%,Not Open to Non-GSB Students
# Seminar in Empirical Accounting Research
# No Exam,Open to GSB PhD students,P/F Allowed with Permission of Instructor,Seminar,Mandatory attendance. Absences impact grade.,MBA2 and MSx students need instructor permission,1 Group 3 Individual Projects/Papers,Participation 20% Proj/Papers30% Presentations 50%,Not Open to Non-GSB Students
# -------
# Applications of Information Economics in Management and Accounting
# Open to GSB PhD students,Non-GSB students: See gsb.stanford.edu/NonGSBReg.,Final 50% Projects/Papers 50%,P/F Allowed with Permission of Instructor,Seminar,In-class Final,Mandatory attendance. Absences impact grade.,1 Individual Project/Paper
# -------
# Financial Reporting Seminar
# No Exam,Open to GSB PhD students,P/F Not Allowed,Participation 20% Projects/Papers 80%,Seminar,4 Individual Projects/Papers,Mandatory attendance. Absences impact grade.,Not Open to Non-GSB Students
# -------
# Selected Topics in Empirical Accounting Research
# No Exam,Participation 50% Projects/Papers 50%,Open to GSB PhD students,P/F Not Allowed,Seminar,Mandatory attendance. Absences impact grade.,Non-GSB students: See gsb.stanford.edu/NonGSBReg.
# -------

# %%
# tags analysis

for i, course in enumerate(a):
    if i < 700:
        continue
    if i > 800:
        break
    #print(i)
    #print(course['title'])
    x = course['tags'] 
    if x: 
        if isinstance(x, list): 
            print(course['title'])
            for i in range(len(x)):
                print(x[i])
            print("******")
        else:
            print('shouldnt be another type')
            break
# Out:
# World Heritage in Global Conflict (ANTHRO 247B, ARCHLGY 147B)
# OrderedDict([(u'organization', u'ISSTUD'), (u'name', u'ALCW12')])
# OrderedDict([(u'organization', u'IR'), (u'name', u'ihc')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Health, Politics, and Culture of Modern China (ANTHRO 248)
# OrderedDict([(u'organization', u'CIGH'), (u'name', u'globalhealth')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# South Asia: History, People, Politics (ANTHRO 249)
# OrderedDict([(u'organization', u'ISSTUD'), (u'name', u'ALCW12')])
# OrderedDict([(u'organization', u'URBANST'), (u'name', u'comphist')])
# OrderedDict([(u'organization', u'IR'), (u'name', u'east_soasia')])
# OrderedDict([(u'organization', u'SGS'), (u'name', u'southasian')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'SOUTHASIA'), (u'name', u'elective')])
# ******
# Cities and Citizens in the Middle East (URBANST 144)
# OrderedDict([(u'organization', u'ISSTUD'), (u'name', u'ALCW12')])
# OrderedDict([(u'organization', u'IR'), (u'name', u'meca')])
# OrderedDict([(u'organization', u'IR'), (u'name', u'socdev')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# The Ordinary: The History of a Concept (ANTHRO 250)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Minaret and Mahallah: Women and Islam in Central Asia (FEMGEN 150A, REES 250A)
# OrderedDict([(u'organization', u'IR'), (u'name', u'meca')])
# OrderedDict([(u'organization', u'IR'), (u'name', u'socdev')])
# OrderedDict([(u'organization', u'ISSTUD'), (u'name', u'ALCW12')])
# OrderedDict([(u'organization', u'SGS'), (u'name', u'iranian')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Contemporary Chinese Society Through Independent Documentary Film (ANTHRO 251A)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'AMWEST'), (u'name', u'gen')])
# ******
# Ritual, Politics, Power (SOC 156)
# OrderedDict([(u'organization', u'IR'), (u'name', u'ihc')])
# OrderedDict([(u'organization', u'IR'), (u'name', u'socdev')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Urban Poverty and Inequality in Contemporary China
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'PUBLPOL'), (u'name', u'elec-urban')])
# ******
# Population and social trends in Japan (ANTHRO 253A)
# OrderedDict([(u'organization', u'SPBK'), (u'name', u'2')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Anthropology of Drugs: Experience, Capitalism, Modernity (ANTHRO 254B, CSRE 154)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'STS'), (u'name', u'io-found')])
# OrderedDict([(u'organization', u'STS'), (u'name', u'io-sc')])
# OrderedDict([(u'organization', u'STS'), (u'name', u'lsh-sc')])
# OrderedDict([(u'organization', u'STS'), (u'name', u'lsh-found')])
# ******
# Research Methods in Ecological Anthropology (ANTHRO 255)
# OrderedDict([(u'organization', u'CSRE'), (u'name', u'methodology')])
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'enviro')])
# OrderedDict([(u'organization', u'ENVRINST'), (u'name', u'af_faculty')])
# OrderedDict([(u'organization', u'NATIVEAM'), (u'name', u'methodology')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'PUBLPOL'), (u'name', u'elec-energy')])
# ******
# Japanese Anthropology (ANTHRO 256)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Environment, Nature and Race (CSRE 156J)
# OrderedDict([(u'organization', u'URBANST'), (u'name', u'socialsustelect')])
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'enviro')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Social and Environmental Sustainability: The Costa Rican Case (ANTHRO 260)
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'enviro')])
# OrderedDict([(u'organization', u'STS'), (u'name', u'ne-sc')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'LATINAM'), (u'name', u'eco')])
# ******
# Tragedy of the Commons: Human Ecology of Communal Resources (ANTHRO 260A)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'SUST'), (u'name', u'elective')])
# ******
# Human Ecology: Adaptations to Climate and Climate Change (ANTHRO 261A)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Indigenous Peoples and Environmental Problems (ANTHRO 262)
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'anthro_sustdev')])
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'bio_ecosoc')])
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'enviro')])
# OrderedDict([(u'organization', u'NATIVEAM'), (u'name', u'affiliated')])
# OrderedDict([(u'organization', u'STS'), (u'name', u'ne-sc')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'HUMRTS'), (u'name', u'issues')])
# OrderedDict([(u'organization', u'STS'), (u'name', u'ne-found')])
# OrderedDict([(u'organization', u'LATINAM'), (u'name', u'eco')])
# OrderedDict([(u'organization', u'CSRE'), (u'name', u'affiliated')])
# OrderedDict([(u'organization', u'SUST'), (u'name', u'elective')])
# OrderedDict([(u'organization', u'PUBLPOL'), (u'name', u'elec-energy')])
# ******
# Conservation and Evolutionary Ecology (ANTHRO 263)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'HUMBIO'), (u'name', u'evo')])
# ******
# Endangered Languages and Language Revitalization (ANTHRO 263A, LINGUIST 163A, LINGUIST 263, NATIVEAM 163)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Natural Resource Extraction: Use and Development: Assessing Policies, Practices and Outcomes (ANTHRO 264)
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'enviro')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Anthropology of Ecotourism
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Anthropology of Tourism
# OrderedDict([(u'organization', u'SPBK'), (u'name', u'2')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Parks and Peoples: The Benefits and Costs of Protected Area Conservation
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'bio_ecosoc')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# People and Parks: Management of Protected Areas
# OrderedDict([(u'organization', u'SPBK'), (u'name', u'2')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Political Ecology of Tropical Land Use: Conservation, Natural Resource Extraction, and Agribusiness (ANTHRO 266)
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'bio_ecosoc')])
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'enviro')])
# OrderedDict([(u'organization', u'ENVRINST'), (u'name', u'faculty')])
# OrderedDict([(u'organization', u'STS'), (u'name', u'pp-sc')])
# OrderedDict([(u'organization', u'STS'), (u'name', u'ne-sc')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'CSI'), (u'name', u'certificate')])
# ******
# A Wilderness Empire: The Political Ecology of California
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'STS'), (u'name', u'core-sshum')])
# ******
# Networks in Anthropology
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Everest: Extreme Anthropology
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'enviro')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Risky Environments: The Nature of Disaster (ANTHRO 268A)
# OrderedDict([(u'organization', u'SPBK'), (u'name', u'2')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'EARTH'), (u'name', u'ice')])
# ******
# The Ecology of Cuisine: Food, Nutrition, and the Evolution of the Human Diet (ANTHRO 269)
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'enviro')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'IEARTH'), (u'name', u'food')])
# ******
# New Citizenship: Grassroots Movements for Social Justice in the U.S. (CHILATST 168, CSRE 168, FEMGEN 140H)
# OrderedDict([(u'organization', u'AMSTUD'), (u'name', u'thematic-concentration')])
# OrderedDict([(u'organization', u'CSRE'), (u'name', u'public-service')])
# OrderedDict([(u'organization', u'HAAS'), (u'name', u'service-learning')])
# OrderedDict([(u'organization', u'HAAS'), (u'name', u'cel')])
# OrderedDict([(u'organization', u'CSRE'), (u'name', u'service-learning')])
# OrderedDict([(u'organization', u'CSRE'), (u'name', u'cel')])
# OrderedDict([(u'organization', u'CARDCOURSES'), (u'name', u'identity')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Australian Ecosystems: Human Dimensions and Environmental Dynamics (ANTHRO 270, EARTHSYS 172)
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'enviro')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Multispecies Ethnography: Human, Animal, Plant, Mineral, and Microbe (ANTHRO 270A)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# The Biology and Evolution of Language (ANTHRO 271, HUMBIO 145L)
# OrderedDict([(u'organization', u'SPBK'), (u'name', u'2')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Linguistic Field Methods
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Seminar on Cultural Evolution and Coevolution (ANTHRO 272)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Anthropology of Gender/Sexuality: Eco-Feminist Persepctives (ANTHRO 272B)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'FEMST'), (u'name', u'all')])
# ******
# Beginnings of Social Complexity (ANTHRO 274)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Human Skeletal Anatomy (ANTHRO 275, BIO 174, BIO 274, HUMBIO 180)
# OrderedDict([(u'organization', u'SPBK'), (u'name', u'3')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Cultures, Minds, and Medicine (ANTHRO 276)
# OrderedDict([(u'organization', u'VPUE'), (u'name', u'cc-wonders')])
# OrderedDict([(u'organization', u'CIGH'), (u'name', u'globalhealth')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Environmental Change and Emerging Infectious Diseases (ANTHRO 277, EARTHSYS 114, EARTHSYS 214, HUMBIO 114)
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'enviro')])
# OrderedDict([(u'organization', u'ENVRINST'), (u'name', u'faculty')])
# OrderedDict([(u'organization', u'SGS'), (u'name', u'african')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'IEARTH'), (u'name', u'risk')])
# ******
# Evolution and Conservation in Galapagos (ANTHRO 278)
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'enviro')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Culture, Narrative, and Medicine
# OrderedDict([(u'organization', u'CIGH'), (u'name', u'globalhealth')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Cultures of Disease: Cancer and HIV/AIDS (ENGLISH 179)
# OrderedDict([(u'organization', u'AMSTUD'), (u'name', u'thematic-concentration')])
# OrderedDict([(u'organization', u'FEMST'), (u'name', u'Cognate')])
# OrderedDict([(u'organization', u'CIGH'), (u'name', u'globalhealth')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'STS'), (u'name', u'core-sshum')])
# OrderedDict([(u'organization', u'PUBLPOL'), (u'name', u'elec-health')])
# ******
# Health, Illness, and Healing in South Asia (ANTHRO 279A)
# OrderedDict([(u'organization', u'CIGH'), (u'name', u'globalhealth')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Science, Technology, and Gender
# OrderedDict([(u'organization', u'FEMST'), (u'name', u'Cognate')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'FEMST'), (u'name', u'all')])
# ******
# Gender in the Middle East: Iran, Turkey, and Egypt (FEMGEN 181A)
# OrderedDict([(u'organization', u'FEMST'), (u'name', u'Cognate')])
# OrderedDict([(u'organization', u'ISSTUD'), (u'name', u'ALCW12')])
# OrderedDict([(u'organization', u'IR'), (u'name', u'meca')])
# OrderedDict([(u'organization', u'IR'), (u'name', u'socdev')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'SGS'), (u'name', u'iranian')])
# ******
# An Anthropology of Annihilation: Tobacco at the Turn of the Millennium
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Down and Out: Marginal Lives and Institutional Technologies (ANTHRO 282A)
# OrderedDict([(u'organization', u'CIGH'), (u'name', u'globalhealth')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Smoke and Mirrors in Global Health
# OrderedDict([(u'organization', u'CIGH'), (u'name', u'globalhealth')])
# OrderedDict([(u'organization', u'PATHWAYS'), (u'name', u'activism')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Human Mobility and Adaptability (ANTHRO 283B)
# OrderedDict([(u'organization', u'URBANST'), (u'name', u'socialsustelect')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'HUMBIO'), (u'name', u'hpf')])
# ******
# Spirituality and Healing
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Medical Anthropology of Contemporary Africa (ANTHRO 285)
# OrderedDict([(u'organization', u'AAAS'), (u'name', u'africa')])
# OrderedDict([(u'organization', u'AAAS'), (u'name', u'related')])
# OrderedDict([(u'organization', u'AAAS'), (u'name', u'ss')])
# OrderedDict([(u'organization', u'AFRICAST'), (u'name', u'min-related')])
# OrderedDict([(u'organization', u'CIGH'), (u'name', u'globalhealth')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Race and Biomedicine (ASNAMST 185A)
# OrderedDict([(u'organization', u'CSRE'), (u'name', u'race-health')])
# OrderedDict([(u'organization', u'FEMST'), (u'name', u'Cognate')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Culture and Madness: Anthropological and Psychiatric Approaches to Mental Illness (ANTHRO 286, HUMBIO 146, PSYC 286)
# OrderedDict([(u'organization', u'STS'), (u'name', u'lsh-sc')])
# OrderedDict([(u'organization', u'STS'), (u'name', u'core-sshum')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'STS'), (u'name', u'core-ss-global')])
# OrderedDict([(u'organization', u'CARDCOURSES'), (u'name', u'health')])
# OrderedDict([(u'organization', u'CARDCOURSES'), (u'name', u'identity')])
# OrderedDict([(u'organization', u'STS'), (u'name', u'lsh-found')])
# OrderedDict([(u'organization', u'VPUE'), (u'name', u'cc-ff')])
# ******
# The Most Rational People in the World
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Nuclear Cultures
# OrderedDict([(u'organization', u'PIE'), (u'name', u'energy')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# The Anthropology of Race, Nature, and Animality (CSRE 187A)
# OrderedDict([(u'organization', u'AAAS'), (u'name', u'africa')])
# OrderedDict([(u'organization', u'AAAS'), (u'name', u'gender')])
# OrderedDict([(u'organization', u'AAAS'), (u'name', u'mixed_race')])
# OrderedDict([(u'organization', u'AAAS'), (u'name', u'related')])
# OrderedDict([(u'organization', u'AAAS'), (u'name', u'ss')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Anthropology Capstone: Contemporary Debates in Anthropology
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Senior and Master's Paper Writing Workshop (ANTHRO 299)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Lifeways of the Ancient Maya (ANTHRO 100B)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Introduction to Cultural and Social Anthropology (ANTHRO 1)
# OrderedDict([(u'organization', u'FEMST'), (u'name', u'Cognate')])
# OrderedDict([(u'organization', u'FEMST'), (u'name', u'cognate-current-year')])
# OrderedDict([(u'organization', u'FEMST'), (u'name', u'Discipl-Srvy-Method-Theory')])
# OrderedDict([(u'organization', u'SPBK'), (u'name', u'2')])
# OrderedDict([(u'organization', u'AFRICAST'), (u'name', u'ma-related')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'FEMST'), (u'name', u'all')])
# OrderedDict([(u'organization', u'FEMST'), (u'name', u'grtheory')])
# ******
# Archaeology of Technology (ANTHRO 101B, ARCHLGY 100, ARCHLGY 200)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Ancient Civilizations: Complexity and Collapse (ANTHRO 102A)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Human Osteoarchaeology (ANTHRO 103A)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Language and Culture (ANTHRO 4)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Ancient Cities in the New World (ANTHRO 105)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Archaeological Fieldwork: Critical Analysis and Practical Application (ANTHRO 105A)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Human Origins (ANTHRO 6, HUMBIO 6)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Incas and their Ancestors: Peruvian Archaeology (ANTHRO 106, ARCHLGY 102B)
# OrderedDict([(u'organization', u'SPBK'), (u'name', u'2')])
# OrderedDict([(u'organization', u'LATINAM'), (u'name', u'culsoc')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Archaeology: World Cultural Heritage (ANTHRO 109)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Archaeology of the Modern World (ANTHRO 109A, ARCHLGY 109A)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Neandertals and Modern Humans: Origin, Evolution, Interactions (ANTHRO 110A)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Examining Ethnographies (ANTHRO 110B)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Archaeology of Sex, Sexuality, and Gender (ANTHRO 111)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Archaeology of the Andes of Argentina (ANTHRO 111A)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Public Archaeology: Market Street Chinatown Archaeology Project (ANTHRO 112, ASNAMST 112)
# OrderedDict([(u'organization', u'HAAS'), (u'name', u'service-learning')])
# OrderedDict([(u'organization', u'HAAS'), (u'name', u'cel')])
# OrderedDict([(u'organization', u'CARDCOURSES'), (u'name', u'identity')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Culture and Epigenetics: Towards A Non-Darwinian Synthesis (ANTHRO 113)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Religious Practices in Archaeological Cultures (ANTHRO 113B, ARCHLGY 113B)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Prehistoric Stone Tools: Technology and Analysis (ANTHRO 114, ARCHLGY 114)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Introduction to South Asian Archaeolgy (ANTHRO 114A, ARCHLGY 114A)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Landscape Archaeology and Global Information Systematics (ANTHRO 114B)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# The Social life of Human Bones (ANTHRO 115, ARCHLGY 115)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Peoples and Cultures of Ancient Mesoamerica (ANTHRO 115B)
# OrderedDict([(u'organization', u'LATINAM'), (u'name', u'culsoc')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Data Analysis for Quantitative Research (ANTHRO 116)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Anthropology of the Environment (ANTHRO 116B)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Thinking Through Animals (ANTHRO 117)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Monuments and Landscapes: An Archaeological Perspective (ANTHRO 117B, ARCHLGY 117B)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Zooarchaeology: An Introduction to Faunal Remains (ANTHRO 119, ARCHLGY 119)
# OrderedDict([(u'organization', u'EARTHSYS'), (u'name', u'enviro')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Language and Prehistory (ANTHRO 121)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Race and Culture in Mexico and Central America (ANTHRO 122A)
# OrderedDict([(u'organization', u'LATINAM'), (u'name', u'culsoc')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
# Research in Maya Hieroglyphic Writing (ANTHRO 122C)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# OrderedDict([(u'organization', u'LATINAM'), (u'name', u'culsoc')])
# ******
# Readings in Linguistic Anthropology (ANTHRO 123)
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove100')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversityabove200')])
# OrderedDict([(u'organization', u'EDUC'), (u'name', u'alluniversity')])
# ******
